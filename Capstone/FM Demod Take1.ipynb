# %%
import numpy as np
from scipy.signal import resample_poly, firwin, bilinear, lfilter
import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display

# Read in signal
# x = np.fromfile('/Users/nattykorb/Documents/GitHub/Capstone/fm_rds_250k_1Msamples.iq', dtype=np.complex64)
x = np.fromfile('/Users/nattykorb/Documents/GitHub/Capstone/SHEARS_LRG_snip_denoised.wav', dtype=np.complex64)
sample_rate = 192e3
center_freq = 1500
#center_freq = 99.5e6

# %%
#IPython.display.Audio(data=x, rate=96e3)

# %%
# Quadrature Demod
ModSig = 0.5 * np.angle(x[0:-1] * np.conj(x[1:])) # see https://wiki.gnuradio.org/index.php/Quadrature_Demod

# %%
IPython.display.Audio(data=ModSig, rate=96e3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
